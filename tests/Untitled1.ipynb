# %%
import numpy as np
from tensorboardX import SummaryWriter
import torch 
from torch.autograd import Variable 
import torch.nn as nn 
import torch.optim as optim 
import torch.nn.functional as F 
import torch.utils.data

# %%
writer = SummaryWriter()

# %%
for epoch in range(100):
    loss = torch.rand(1)  
    writer.add_scalar('loss', {'training_loss': loss}, epoch)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-7b58feb44f87> in <module>()
#       1 for epoch in range(100):
#       2     loss = torch.rand(1)
# ----> 3     writer.add_scalar('loss', {'training_loss': loss}, epoch)
#
# /home/hikaru/anaconda3/lib/python3.6/site-packages/tensorboardX/writer.py in add_scalar(self, tag, scalar_value, global_step)
#     260
#     261         """
# --> 262         self.file_writer.add_summary(scalar(tag, scalar_value), global_step)
#     263         self.__append_to_scalar_dict(tag, float(scalar_value), global_step, time.time())
#     264
#
# /home/hikaru/anaconda3/lib/python3.6/site-packages/tensorboardX/summary.py in scalar(name, scalar, collections)
#      86     name = _clean_tag(name)
#      87     scalar = makenp(scalar)
# ---> 88     assert(scalar.squeeze().ndim==0), 'scalar should be 0D'
#      89     scalar = float(scalar)
#      90     return Summary(value=[Summary.Value(tag=name, simple_value=scalar)])
#
# AttributeError: 'NoneType' object has no attribute 'squeeze'
